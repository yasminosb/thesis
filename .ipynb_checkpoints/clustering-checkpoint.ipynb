# %%
import pandas as pd
import json
import matplotlib as matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from ipynb.fs.full.common import *

# %%
gameplays = pd.json_normalize(pd.Series(open(r"C:\Users\Yasmine Bogaert\Documents\thesis\dump\dump_30-03-2021\csv\gameplays.json").readlines()).apply(json.loads))

# %%
gameplays = preprocess_gameplays(gameplays)

# %%
gameplays = add_distance_per_jump(gameplays)

# %%
# umap needs numeric values
gameplays = convert_collisionObstacle_numeric(gameplays)

# %%
import pandas as pd
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)

interesting_parameters = parameters + ['distance_per_jump']
y = kmeans.fit_predict(gameplays[interesting_parameters])

gameplays['Cluster'] = y

gameplays.loc[gameplays['Cluster'] == 2][interesting_parameters + ['Cluster']].head(10)
#print(gameplays[['actualDistance', 'nr_jumps', 'Cluster']].head(10))
# Out:
#      parameters.SPEED  parameters.ACCELERATION  parameters.MIN_GAP  \
# 27                 10                    0.002                 393
# 28                 10                    0.002                 342
# 34                  7                    0.002                 378
# 60                  5                    0.002                 348
# 62                  8                    0.002                 343
# 102                 5                    0.002                 337
# 111                 5                    0.002                 362
# 143                 6                    0.002                 348
# 211                 5                    0.002                 387
# 318                 9                    0.002                 390
#
#      parameters.NIGHT_MODE_ENABLED  parameters.NIGHT_MODE_DISTANCE  \
# 27                           False                             600
# 28                            True                             900
# ...

# %%
gameplays[interesting_parameters].head(10)
# Out:
#    parameters.SPEED  parameters.ACCELERATION  parameters.MIN_GAP  \
# 0                 7                    0.002                 382
# 1                 7                    0.002                 382
# 2                 5                    0.002                 276
# 3                 5                    0.002                 276
# 4                 9                    0.002                 325
# 5                 8                    0.002                 296
# 6                 9                    0.002                 265
# 7                 5                    0.002                 379
# 8                 7                    0.002                 280
# 9                 9                    0.002                 336
#
#    parameters.NIGHT_MODE_ENABLED  parameters.NIGHT_MODE_DISTANCE  \
# 0                           True                             800
# 1                           True                             800
# ...

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics


def afstand(x,y):
    print("x:" + str(x))
    print("y:" + str(y) + "\n")
    return 0



# get relevant data and scale it 
interesting_parameters = parameters + ['distance_per_jump']
data = gameplays[interesting_parameters]
#scaled_data = scale_data(data)

# ??
print(data['parameters.SPEED'].groupby([data['parameters.SPEED']]).count())

# run DBSCAN
dbscan = DBSCAN(eps = 0.3, min_samples = 3, metric=afstand).fit(data)
core_samples_mask = np.zeros_like(dbscan.labels_, dtype=bool)
core_samples_mask[dbscan.core_sample_indices_] = True
labels = dbscan.labels_
print(labels)

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
 
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# parameters.SPEED
# 5     163
# 6     167
# 7     169
# 8     180
# 9     177
# 10    197
# Name: parameters.SPEED, dtype: int64
# x:[7.60018993e+00 1.43456790e-02 3.24405508e+02 4.75783476e-01
#  6.39506173e+02 2.91552422e+03 2.02279202e+00 1.13076923e+01
#  3.63270655e+02 3.64021842e+02 9.98100665e-01 3.02744539e+01
#  5.12820513e-02 2.11134020e+01]
# y:[7.00000000e+00 2.00000000e-03 3.82000000e+02 1.00000000e+00
#  8.00000000e+02 2.57300000e+03 1.00000000e+00 8.00000000e+00
#  3.86000000e+02 4.60000000e+01 0.00000000e+00 3.00000000e+00
#  0.00000000e+00 1.53333333e+01]
#
# x:[7.60018993e+00 1.43456790e-02 3.24405508e+02 4.75783476e-01
#  6.39506173e+02 2.91552422e+03 2.02279202e+00 1.13076923e+01
#  3.63270655e+02 3.64021842e+02 9.98100665e-01 3.02744539e+01
#  5.12820513e-02 2.11134020e+01]
# y:[7.000e+00 2.000e-03 3.820e+02 1.000e+00 8.000e+02 2.573e+03 1.000e+00
#  8.000e+00 3.860e+02 6.200e+01 0.000e+00 4.000e+00 0.000e+00 1.550e+01]
#
# ...
